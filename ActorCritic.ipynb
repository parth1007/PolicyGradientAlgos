# %%
import os
import gym
import pylab
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from collections import deque
import tensorflow_probability as tfp
from keras.layers import Input, Dense
from keras.models import Model, load_model
from keras.optimizers import Adam, RMSprop



class Callback(tf.keras.callbacks.Callback):
    SHOW_NUMBER = 10
    counter = 0
    epoch = 0

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch = epoch

    def on_train_batch_end(self, batch, logs=None):
        if self.counter == self.SHOW_NUMBER or self.epoch == 1:
            # print('Epoch: ' + str(self.epoch) + ' loss: ' + str(logs['loss']))
            if self.epoch > 1:
                self.counter = 0
        self.counter += 1



RANDOM_SEED = 6
tf.random.set_seed(RANDOM_SEED)

env = gym.make('CartPole-v1',new_step_api=True)
np.random.seed(RANDOM_SEED)
env.reset(seed = RANDOM_SEED)
action_shape = env.action_space.n
state_shape = env.observation_space.shape


train_episodes = 300
learning_rate = 0.001
gamma = .9


tf.keras.backend.clear_session()


def actor_model(state_shape, action_shape):
    init = tf.keras.initializers.HeUniform()
    model = keras.Sequential()
    model.add(keras.layers.Dense(24, input_shape=state_shape, activation=tf.keras.layers.LeakyReLU(), kernel_initializer=init))
    model.add(keras.layers.Dense(12, activation=tf.keras.layers.LeakyReLU(), kernel_initializer=init))
    model.add(keras.layers.Dense(action_shape, activation='softmax', kernel_initializer=init))
    model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), metrics=['accuracy'])
    return model

def critic_model(state_shape):
    init = tf.keras.initializers.HeUniform()
    model = keras.Sequential()
    model.add(keras.layers.Dense(24, input_shape=state_shape, activation=tf.keras.layers.LeakyReLU(), kernel_initializer=init))
    model.add(keras.layers.Dense(12, activation=tf.keras.layers.LeakyReLU(), kernel_initializer=init))
    model.add(keras.layers.Dense(1, activation='linear', kernel_initializer=init))
    model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), metrics=['accuracy'])
    return model



def one_hot_encode_action(action, n_actions):
    encoded = np.zeros(n_actions, np.float32)
    encoded[action] = 1
    return encoded

def main():

    actor = actor_model(state_shape, action_shape)
    critic = critic_model(state_shape)

    for episode in range(train_episodes):
        state = env.reset()
        done = False
        num_steps = 0
        while not done:
            num_steps += 1

            # model dims are (batch, state_shape)
            state_reshaped = state.reshape([1, state.shape[0]])
            action_probs = actor.predict(state_reshaped, verbose=0, callbacks=[Callback()]).flatten()

            # Sampling from the prob distribution instead of using argmax
            action = np.random.choice(action_shape, 1, p=action_probs)[0]
            encoded_action = one_hot_encode_action(action, action_shape)

            next_state, reward, done, _,_ = env.step(action)
            next_state_reshaped = next_state.reshape([1, next_state.shape[0]])


            # Calculating Advantage
            v_curr = np.ndarray.item(critic.predict(state_reshaped, verbose=0, callbacks=[Callback()]))
            v_next = np.ndarray.item(critic.predict(next_state_reshaped, verbose=0, callbacks=[Callback()]))
            TD_target = reward + (1 - done) * gamma * v_next
            advantage = TD_target - v_curr


            # Training Critic model
            advantage_reshaped = np.vstack([advantage])
            TD_target = np.vstack([TD_target])
            critic.train_on_batch(state_reshaped, TD_target)
            #critic.fit(state_reshaped, TD_target, verbose=0)


            # Training Actor model
            gradient = encoded_action - action_probs
            gradient_with_advantage = .0001 * gradient * advantage_reshaped + action_probs
            actor.train_on_batch(state_reshaped, gradient_with_advantage)
            #actor.fit(state_reshaped, gradient_with_advantage, verbose=0)
            state = next_state

            if done:
                print('Episode => {} ::: Total steps=> {}'.format(episode,num_steps))

    env.close()

main()
# Out:
# Episode => 0 ::: Total steps=> 23
# Episode => 1 ::: Total steps=> 13
# Episode => 2 ::: Total steps=> 37
# Episode => 3 ::: Total steps=> 46
# Episode => 4 ::: Total steps=> 60
# Episode => 5 ::: Total steps=> 25
# Episode => 6 ::: Total steps=> 23
# Episode => 7 ::: Total steps=> 11
# Episode => 8 ::: Total steps=> 11
# Episode => 9 ::: Total steps=> 13
# Episode => 10 ::: Total steps=> 9
# Episode => 11 ::: Total steps=> 8
# Episode => 12 ::: Total steps=> 13
# Episode => 13 ::: Total steps=> 14
# Episode => 14 ::: Total steps=> 12
# Episode => 15 ::: Total steps=> 9
# Episode => 16 ::: Total steps=> 16
# Episode => 17 ::: Total steps=> 9
# Episode => 18 ::: Total steps=> 12
# Episode => 19 ::: Total steps=> 14
# Episode => 20 ::: Total steps=> 11
# Episode => 21 ::: Total steps=> 9
# Episode => 22 ::: Total steps=> 26
# Episode => 23 ::: Total steps=> 15
# Episode => 24 ::: Total steps=> 10
# Episode => 25 ::: Total steps=> 9
# Episode => 26 ::: Total steps=> 10
# Episode => 27 ::: Total steps=> 8
# Episode => 28 ::: Total steps=> 10
# Episode => 29 ::: Total steps=> 15
# Episode => 30 ::: Total steps=> 10
# Episode => 31 ::: Total steps=> 10
# Episode => 32 ::: Total steps=> 13
# Episode => 33 ::: Total steps=> 10
# Episode => 34 ::: Total steps=> 10
# Episode => 35 ::: Total steps=> 10
# Episode => 36 ::: Total steps=> 8
# Episode => 37 ::: Total steps=> 9
# Episode => 38 ::: Total steps=> 10
# Episode => 39 ::: Total steps=> 10
# Episode => 40 ::: Total steps=> 10
# Episode => 41 ::: Total steps=> 12
# Episode => 42 ::: Total steps=> 10
# Episode => 43 ::: Total steps=> 10
# Episode => 44 ::: Total steps=> 9
# Episode => 45 ::: Total steps=> 9
# Episode => 46 ::: Total steps=> 8
# Episode => 47 ::: Total steps=> 11
# Episode => 48 ::: Total steps=> 11
# Episode => 49 ::: Total steps=> 9
# Episode => 50 ::: Total steps=> 10
# Episode => 51 ::: Total steps=> 9
# Episode => 52 ::: Total steps=> 10
# Episode => 53 ::: Total steps=> 9
# Episode => 54 ::: Total steps=> 10
# Episode => 55 ::: Total steps=> 8
# Episode => 56 ::: Total steps=> 12
# Episode => 57 ::: Total steps=> 10
# Episode => 58 ::: Total steps=> 8
# Episode => 59 ::: Total steps=> 9
# Episode => 60 ::: Total steps=> 10
# Episode => 61 ::: Total steps=> 12
# Episode => 62 ::: Total steps=> 9
# Episode => 63 ::: Total steps=> 10
# Episode => 64 ::: Total steps=> 8
# Episode => 65 ::: Total steps=> 14
# Episode => 66 ::: Total steps=> 9
# Episode => 67 ::: Total steps=> 10
# Episode => 68 ::: Total steps=> 10
# Episode => 69 ::: Total steps=> 10
# Episode => 70 ::: Total steps=> 12
# Episode => 71 ::: Total steps=> 9
# Episode => 72 ::: Total steps=> 9
# Episode => 73 ::: Total steps=> 9
# Episode => 74 ::: Total steps=> 9
# Episode => 75 ::: Total steps=> 10
# Episode => 76 ::: Total steps=> 10
# Episode => 77 ::: Total steps=> 9
# Episode => 78 ::: Total steps=> 15
# Episode => 79 ::: Total steps=> 9
# Episode => 80 ::: Total steps=> 8
# Episode => 81 ::: Total steps=> 9
# Episode => 82 ::: Total steps=> 9
# Episode => 83 ::: Total steps=> 10
# Episode => 84 ::: Total steps=> 9
# Episode => 85 ::: Total steps=> 11
# Episode => 86 ::: Total steps=> 12
# Episode => 87 ::: Total steps=> 9
# Episode => 88 ::: Total steps=> 12
# Episode => 89 ::: Total steps=> 10
# Episode => 90 ::: Total steps=> 10
# Episode => 91 ::: Total steps=> 10
# Episode => 92 ::: Total steps=> 10
# Episode => 93 ::: Total steps=> 9
# Episode => 94 ::: Total steps=> 10
# Episode => 95 ::: Total steps=> 13
# Episode => 96 ::: Total steps=> 10
# Episode => 97 ::: Total steps=> 8
# Episode => 98 ::: Total steps=> 10
# Episode => 99 ::: Total steps=> 12
# Episode => 100 ::: Total steps=> 9
# Episode => 101 ::: Total steps=> 10
# Episode => 102 ::: Total steps=> 12
# Episode => 103 ::: Total steps=> 10
# Episode => 104 ::: Total steps=> 12
# Episode => 105 ::: Total steps=> 9
# Episode => 106 ::: Total steps=> 11
# Episode => 107 ::: Total steps=> 11
# Episode => 108 ::: Total steps=> 14
# Episode => 109 ::: Total steps=> 12
# Episode => 110 ::: Total steps=> 10
# Episode => 111 ::: Total steps=> 14
# Episode => 112 ::: Total steps=> 10
# Episode => 113 ::: Total steps=> 12
# Episode => 114 ::: Total steps=> 15
# Episode => 115 ::: Total steps=> 43
# Episode => 116 ::: Total steps=> 12
# Episode => 117 ::: Total steps=> 20
# Episode => 118 ::: Total steps=> 13
# Episode => 119 ::: Total steps=> 41
# Episode => 120 ::: Total steps=> 25
# Episode => 121 ::: Total steps=> 22
# Episode => 122 ::: Total steps=> 22
# Episode => 123 ::: Total steps=> 54
# Episode => 124 ::: Total steps=> 26
# Episode => 125 ::: Total steps=> 17
# Episode => 126 ::: Total steps=> 34
# Episode => 127 ::: Total steps=> 15
# Episode => 128 ::: Total steps=> 19
# Episode => 129 ::: Total steps=> 58
# Episode => 130 ::: Total steps=> 12
# Episode => 131 ::: Total steps=> 24
# Episode => 132 ::: Total steps=> 16
# Episode => 133 ::: Total steps=> 15
# Episode => 134 ::: Total steps=> 10
# Episode => 135 ::: Total steps=> 73
# Episode => 136 ::: Total steps=> 11
# Episode => 137 ::: Total steps=> 32
# Episode => 138 ::: Total steps=> 22
# Episode => 139 ::: Total steps=> 13
# Episode => 140 ::: Total steps=> 31
# Episode => 141 ::: Total steps=> 19
# Episode => 142 ::: Total steps=> 41
# Episode => 143 ::: Total steps=> 28
# Episode => 144 ::: Total steps=> 62
# Episode => 145 ::: Total steps=> 32
# Episode => 146 ::: Total steps=> 28
# Episode => 147 ::: Total steps=> 90
# Episode => 148 ::: Total steps=> 43
# Episode => 149 ::: Total steps=> 28
# Episode => 150 ::: Total steps=> 30
# Episode => 151 ::: Total steps=> 105
# Episode => 152 ::: Total steps=> 109
# Episode => 153 ::: Total steps=> 166
# Episode => 154 ::: Total steps=> 63
# Episode => 155 ::: Total steps=> 164
# Episode => 156 ::: Total steps=> 108
# Episode => 157 ::: Total steps=> 142
# Episode => 158 ::: Total steps=> 170
# Episode => 159 ::: Total steps=> 128
# Episode => 160 ::: Total steps=> 35
# Episode => 161 ::: Total steps=> 67
# Episode => 162 ::: Total steps=> 62
# Episode => 163 ::: Total steps=> 77
# Episode => 164 ::: Total steps=> 65
# Episode => 165 ::: Total steps=> 50
# Episode => 166 ::: Total steps=> 39
# Episode => 167 ::: Total steps=> 30
# Episode => 168 ::: Total steps=> 41
# Episode => 169 ::: Total steps=> 21
# Episode => 170 ::: Total steps=> 46
# Episode => 171 ::: Total steps=> 46
# Episode => 172 ::: Total steps=> 31
# Episode => 173 ::: Total steps=> 29
# Episode => 174 ::: Total steps=> 63
# Episode => 175 ::: Total steps=> 54
# Episode => 176 ::: Total steps=> 65
# Episode => 177 ::: Total steps=> 27
# Episode => 178 ::: Total steps=> 77
# Episode => 179 ::: Total steps=> 55
# Episode => 180 ::: Total steps=> 37
# Episode => 181 ::: Total steps=> 47
# Episode => 182 ::: Total steps=> 70
# Episode => 183 ::: Total steps=> 92
# Episode => 184 ::: Total steps=> 63
# Episode => 185 ::: Total steps=> 70
# Episode => 186 ::: Total steps=> 41
# Episode => 187 ::: Total steps=> 72
# Episode => 188 ::: Total steps=> 58
# Episode => 189 ::: Total steps=> 61
# Episode => 190 ::: Total steps=> 40
# Episode => 191 ::: Total steps=> 88
# Episode => 192 ::: Total steps=> 45
# Episode => 193 ::: Total steps=> 50
# Episode => 194 ::: Total steps=> 56
# Episode => 195 ::: Total steps=> 38
# Episode => 196 ::: Total steps=> 54
# Episode => 197 ::: Total steps=> 79
# Episode => 198 ::: Total steps=> 69
# Episode => 199 ::: Total steps=> 56
# Episode => 200 ::: Total steps=> 47
# Episode => 201 ::: Total steps=> 139
# Episode => 202 ::: Total steps=> 59
# Episode => 203 ::: Total steps=> 55
# Episode => 204 ::: Total steps=> 59
# Episode => 205 ::: Total steps=> 72
# Episode => 206 ::: Total steps=> 59
# Episode => 207 ::: Total steps=> 60
# Episode => 208 ::: Total steps=> 77
# Episode => 209 ::: Total steps=> 35
# Episode => 210 ::: Total steps=> 72
# Episode => 211 ::: Total steps=> 54
# Episode => 212 ::: Total steps=> 67
# Episode => 213 ::: Total steps=> 45
# Episode => 214 ::: Total steps=> 57
# Episode => 215 ::: Total steps=> 39
# Episode => 216 ::: Total steps=> 38
# Episode => 217 ::: Total steps=> 46
# Episode => 218 ::: Total steps=> 74
# Episode => 219 ::: Total steps=> 36
# Episode => 220 ::: Total steps=> 48
# Episode => 221 ::: Total steps=> 36
# Episode => 222 ::: Total steps=> 49
# Episode => 223 ::: Total steps=> 45
# Episode => 224 ::: Total steps=> 30
# Episode => 225 ::: Total steps=> 36
# Episode => 226 ::: Total steps=> 33
# Episode => 227 ::: Total steps=> 49
# Episode => 228 ::: Total steps=> 38
# Episode => 229 ::: Total steps=> 46
# Episode => 230 ::: Total steps=> 124
# Episode => 231 ::: Total steps=> 80
# Episode => 232 ::: Total steps=> 51
# Episode => 233 ::: Total steps=> 45
# Episode => 234 ::: Total steps=> 43
# Episode => 235 ::: Total steps=> 39
# Episode => 236 ::: Total steps=> 93
# Episode => 237 ::: Total steps=> 32
# Episode => 238 ::: Total steps=> 43
# Episode => 239 ::: Total steps=> 40
# Episode => 240 ::: Total steps=> 51
# Episode => 241 ::: Total steps=> 53
# Episode => 242 ::: Total steps=> 50
# Episode => 243 ::: Total steps=> 42
# Episode => 244 ::: Total steps=> 44
# Episode => 245 ::: Total steps=> 50
# Episode => 246 ::: Total steps=> 52
# Episode => 247 ::: Total steps=> 68
# Episode => 248 ::: Total steps=> 33
# Episode => 249 ::: Total steps=> 51
# Episode => 250 ::: Total steps=> 51
# Episode => 251 ::: Total steps=> 50
# Episode => 252 ::: Total steps=> 45
# Episode => 253 ::: Total steps=> 45
# Episode => 254 ::: Total steps=> 81
# Episode => 255 ::: Total steps=> 68
# Episode => 256 ::: Total steps=> 51
# Episode => 257 ::: Total steps=> 93
# Episode => 258 ::: Total steps=> 123
# Episode => 259 ::: Total steps=> 139
# Episode => 260 ::: Total steps=> 98
# Episode => 261 ::: Total steps=> 94
# Episode => 262 ::: Total steps=> 128
# Episode => 263 ::: Total steps=> 94
# Episode => 264 ::: Total steps=> 81
# Episode => 265 ::: Total steps=> 69
# Episode => 266 ::: Total steps=> 95
# Episode => 267 ::: Total steps=> 72
# Episode => 268 ::: Total steps=> 82
# Episode => 269 ::: Total steps=> 84
# Episode => 270 ::: Total steps=> 81
# Episode => 271 ::: Total steps=> 74
# Episode => 272 ::: Total steps=> 101
# Episode => 273 ::: Total steps=> 88
# Episode => 274 ::: Total steps=> 92
# Episode => 275 ::: Total steps=> 94
# Episode => 276 ::: Total steps=> 97
# Episode => 277 ::: Total steps=> 106
# Episode => 278 ::: Total steps=> 76
# Episode => 279 ::: Total steps=> 70
# Episode => 280 ::: Total steps=> 106
# Episode => 281 ::: Total steps=> 78
# Episode => 282 ::: Total steps=> 115
# Episode => 283 ::: Total steps=> 61
# Episode => 284 ::: Total steps=> 107
# Episode => 285 ::: Total steps=> 101
# Episode => 286 ::: Total steps=> 100
# Episode => 287 ::: Total steps=> 94
# Episode => 288 ::: Total steps=> 95
# Episode => 289 ::: Total steps=> 103
# Episode => 290 ::: Total steps=> 88
# Episode => 291 ::: Total steps=> 98
# Episode => 292 ::: Total steps=> 112
# Episode => 293 ::: Total steps=> 116
# Episode => 294 ::: Total steps=> 100
# Episode => 295 ::: Total steps=> 94
# Episode => 296 ::: Total steps=> 110
# Episode => 297 ::: Total steps=> 88
# Episode => 298 ::: Total steps=> 94
# Episode => 299 ::: Total steps=> 101
